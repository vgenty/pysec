# %%
from pysec.util import company_utilities as cu

T = 'AAPL'

a = cu.get_company_df(T,'q')
a = cu.build_xbrl(a)
# Out:
# 3.09944152832e-06
# 0.673409938812
# Got acc table...
# 0.110929012299
# Threaded out the fifo...
# 0.141182899475
# finished waiting for sec...
# 0.00917100906372
# pulled data out of FIFO
# 9.53674316406e-07
# built XBRL objects...
# pysec/util/company_utilities.py:27: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
#for i in xrange(18): print a['xbrl'].ix[i].fields['NetIncomeLoss']
#for i in xrange(18): print a['xbrl'].ix[i].fields['NetIncomeLoss']
cu.calculate_ratios(a)
# Out:
# ['Cash', '+', 'MarketableSecurities', '/', 'AccountsReceivable']
# 3
# Cash
# 0.0
# MarketableSecurities
# 5605000000.0
# ['CurrentAssets', '/', 'CurrentLiabilities']
# 1
# CurrentAssets
# 0.0
# ['Cash', '+', 'MarketableSecurities', '+', 'AccountsReceivable', '/', 'CurrentLiabilities']
# 5
# Cash
# 0.0
# MarketableSecurities
# 5605000000.0
# AccountsReceivable
# 24222000000.0
# ['CurrentDebt', '+', 'LongTermDebt', '/', 'CurrentDebt', '+', 'LongTermDebt', '+', 'Equity']
# 3
# CurrentDebt
# bad ratio
# 0.0
# LongTermDebt
# bad ratio
# 0.0
# bad ratio
# bad ratio
# ['CurrentDebt', '+', 'LongTermDebt', '/', 'Equity']
# 3
# CurrentDebt
# bad ratio
# 0.0
# LongTermDebt
# bad ratio
# 0.0
# ['NetIncomeLoss', '/', 'Assets']
# 1
# NetIncomeLoss
# 0.0
# ['NetIncomeLoss', '/', 'Equity']
# 1
# NetIncomeLoss
# 0.0
# ['NetIncomeLoss', '/', 'CurrentDebt', '+', 'LongTermDebt', '+', 'Equity']
# 1
# NetIncomeLoss
# 0.0
# bad ratio
# bad ratio
# ...

# %%
a.Ratios.
# Out:
# 18    {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 17    {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 16    {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 15    {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 14    {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 13    {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 12    {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 11    {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 10    {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 9     {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 8     {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 7     {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 6     {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 5     {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 4     {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 3     {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# 2     {u'Liquidity Analysis': {u'Cash Ratio': (['Cas...
# ...

# %%
print j.GetFactValue('us-gaap:StockholdersEquity','Instant')

# %%
j.fields

# %%
print j

# %%
print a
